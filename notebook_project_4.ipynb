# %% [markdown]
# **Comentario del Revisor**
#
# Hola!
#
# Soy Juan Manuel Romero, pero siéntete libre de llamarme Juanma. Soy code reviewer en Tripleten y hoy estaré revisando tu entrega.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Solo un aviso rápido: cuando estés revisando el proyecto, por favor deja mis comentarios originales tal como están. De esta manera, podemos seguir fácilmente el progreso y asegurarnos de que no se nos pase nada por alto. Y, si realizas algún cambio basado en mis comentarios, sería genial si pudieras resaltar esas actualizaciones para que se destaquen.
#
# Puedes encontrar mis comentarios en cajas verdes, amarillas o rojas como estas:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Éxito. Todo se ha hecho correctamente.
#
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
#
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del Revisor</b> <a class="tocSkip"></a>
#
# Requiere corrección. El bloque requiere algunas correcciones. El trabajo no puede ser aceptado con los comentarios en rojo.
#
# </div>
#
# Puedes responderme usando esto:
#
# <div class="alert alert-block alert-info"> <b>Respuesta del estudiante.</b> <a class="tocSkip"></a> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>COMENTARIO GENERAL #1</b> <a class="tocSkip"></a>
#
# Felicidades Christian! Tu trabajo es excelente.
#
# Has completado todos los items necesarios para aprobar la entrega.
#
# Sigue así!
#
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
import pandas as pd
from matplotlib import pyplot as plt # importar librerías

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al separar la importación de bibliotecas de la carga de los datasets! Esto mejora la estructura y claridad de tu código.
#
# </div>

# %%
df = pd.read_csv('/datasets/instacart_orders.csv', sep=";")
df2 = pd.read_csv('/datasets/products.csv', sep=";")
df3 = pd.read_csv('/datasets/aisles.csv', sep=";")
df4 = pd.read_csv('/datasets/departments.csv', sep=";")
df5 = pd.read_csv('/datasets/order_products.csv', sep=";") # leer conjuntos de datos en los DataFrames

# %%
df.info()
print()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %%
df2.info()
print() 
df2.head() # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %%
df3.info()
print() 
df3.head(5) # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df4.info()
print() 
df4.head(5) # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto! Es bueno incluir el parámetro `show_counts=True` al explorar el DataFrame `order_products`. Esto proporciona una visión más clara de los datos no nulos y es una buena práctica para datasets grandes.
#
# </div>

# %%
df5.info(show_counts=True)
print() 
df5.head(5) # mostrar información del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Muy buen uso de métodos como _info_ y _head_ para la exploración de datos.
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# Tenemos 5 DataFrames de las cuales todas cuentan con una sola columna, esto es porque pandas no logro detectar que en realidad son mas columnas pero que estan separadas por un ";" necesitare realizar la separacion de esas columnas para empezar, asi como tambien la separacion de las filas que tambien todo esta separado por un punto y coma.
#
# La denominada DF5 es la que tiene mas informacion con 454007 entradas, y la DF4 es la que tiene menos informacion con apenas 21 entradas
#
# Veo que en las columnas, todos los datos son numeros, tendre que asegurarme de que python sepa cual quiero tener como Float o int y cuales quiero que se queden como String, por ejemplo el user_id, order_dow quiero que se quede como string.
# Tambien tendre que modificar el order hour para tenerlo como hora y no como un int.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo al incluir conclusiones intermedias sobre la vista general de los datos
#
# </div>

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# Primero, regresare al paso 2, y utilizare sep=";" para que pandas sepa que todo esta separado por";"
# Segundo, utilice info() para revisar que las columnas id pandas los reconoce como numeros enteros "int"
# Tercero, utilizare dropna inplace para eliminar valores ausentes y seguir trabajando en el Dataframe original
# cuarto, utilizare drop.duplicates() para eliminar los duplicados del dataFrame
#
# En el Df en la columna " days_since_prior_order" tengo un total de 28,819 valores ausentes
# En el DF2 en la columna " product_name" tengo un total de 1257 valores ausentes
# En el Df5 en la columna " add_to_cart_order" tengo un total de 836 valores ausentes
# utilizando info() me di cuenta de los valores ausentes de los dataframes

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Es correcto que abordes primero los valores duplicados antes de llenar los valores ausentes. Si eliminas duplicados después, podrías haber trabajado innecesariamente en filas que no eran relevantes para el análisis. Esto te permite ahorrar tiempo y esfuerzo mientras aseguras que los datos sean consistentes desde el principio.
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
df.duplicated().sum()
print()
df[df.duplicated()]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.

# %% [markdown]
# ¿Qué sugiere este resultado?

# %%
# Elimina los pedidos duplicados
df = df.drop_duplicates()

# %%
# Vuelve a verificar si hay filas duplicadas
df.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
df.duplicated(subset='order_id').sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Al revisar el Dataframe "df" o "instacart_orders" se encontro con con 15 lineas duplicadas, todas son de pedidos diferentes realizados a las 2:00am
#
# Podria ser que como tenemos la columna "order_hour_of_day" y esta solo devuelve numeros enteros, podria ser que todas esas 15 compras hallan sido realizadas en una hora ese mismo dia
#
# Por otro lado, podria revelar un glitch o un reinicio de sistema en el sistema que registra el reloj en esa columna?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al identificar los duplicados en `orders`, especialmente aquellos relacionados con pedidos realizados a las 2:00 AM los miércoles!
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Recuerda aplicar `.reset_index(drop=True)` después de `.drop_duplicates()`, lo cual es una buena práctica.
#
# </div>
#
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
df2.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay ID de productos duplicados
df2['product_name'].duplicated().sum()
# Out:
# 1257

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
df2['product_name'] = df2['product_name'].str.upper()

# %%
# Revisa si hay nombres duplicados de productos no faltantes
df2['product_name'].duplicated().sum()
# Out:
# 1361

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# primero use df2.duplicated().sum() para revisar que no hubiera FILAS duplicadas
#
# luego utilice df2['product_name'].duplicated().sum() para de esa fila cuantos duplicados existen, el resultado fue 1257, y cuando las cambie a mayusculas el numero aumento a 1361, por lo tanto quiere decir que solia haber nombres repetidos que pandas no detecto (de hecho yo tampoco me di cuenta) podria haber sido cualquier nombre de producto que al inicio tenia una mayuscula y otro producto igual pero que no llevaba mayusculas

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# En este paso lo importante es detectar que hay productos con el mismo nombre, pero distintos ID's de producto. Probablemente son productos diferentes por lo que no se tratan como duplicados, luego, la tabla `products` no contiene realmente valores duplicados.
#
# Pero lo interesante es realizar este análisis.
#
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df4.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
df4['department'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# no hay duplicados en departamentos esto quiere decir que de los 21 filas que hay existen 21 diferentes departamentos

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df3.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
df3['aisle'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# no hay duplicados de pasillos, de todos los 134 filas, todas son pasillos diferentes

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto, no hay duplicados en _departments_ ni en _aisles_.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df5.duplicated().sum()
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
df5['order_id'].duplicated().sum()
# Out:
# 4094961

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# parece ser que en la columna order_id , el numero de orden tiene algunos duplicados, lo cual es raro, los numeros de ordenes deberian de ser numeros unicos

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# No verificaste duplicados en el subconjunto `['order_id', 'product_id']`. Esto es importante porque ningún producto debería aparecer más de una vez por pedido.
#
# Si no utilizas _subset_ para controlar estas columnas por separado, puede que se nos pase por alto.
#
# Sin embargo, tampoco hay duplicados en este caso.
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
df2.isnull().sum()
# Out:
# product_id          0
# product_name     1258
# aisle_id            0
# department_id       0
# dtype: int64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# existen un total de 1258 valores nulos en la columna product_name, es la unica columna con valores no nulos

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
df2[df2['product_name'].isnull()]
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# podria ser que no exista en si el pasillo numero 100, o puede product_name sea utilizado para productos nuevos que aun no entran? como por asi decirlo una fila vacia para poner cosas?

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# ok tenemos un patron, tenemos product_name con datos ausentes, y todas las veces que estan todas en el departamento 21 y en el pasillo 100

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# revisando las tablas revise y el pasillo 100 y el departamento 21 aparecen como "missing", lo cual me resulta raro,
# ya que "missing" en teoria es un string asi que deberia de poder verlo pandas
# o puede que no sea un string y literalmente me este diciendo missing y falto poner la informacion en la tabla?

# %%
# Completa los nombres de productos ausentes con 'Unknown'
df2['product_name'] = df2['product_name'].fillna("Unknown")

df2.isnull().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# utilice fillna para rellenar los valores nulos con "unknown" no va a afectar mucho porque solian ser 1258 en un Dataframe
# con un total de 49693 entradas, un total menor a 2.5% no deberia haber mucho problema.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al identificar los valores ausentes en `product_name` y asociarlos con las columnas `aisle_id` y `department_id`! Reemplazar estos valores con `'Unknown'` es una decisión lógica y adecuada.
#
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
df.isnull().sum()
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Parece solo haber datos nulos en "days_since_prior_order" no deberia ser un problema este dato y no necesito corregirlo ya que puede que halla dias donde se compre el mismo producto o veces en que se realiza un pedido por primera vez

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Identificaste correctamente que los valores ausentes en `days_since_prior_order` corresponden a `order_number == 1`! Dejar los valores como `NaN` o usar un valor razonable asegura que los datos se manejen correctamente.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Sin embargo no queda claro cómo llegaste a ver este patrón.
#
# </div>
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
df5.isnull().sum()
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
df5['add_to_cart_order'].agg(['min', 'max'])
# Out:
# min     1.0
# max    64.0
# Name: add_to_cart_order, dtype: float64

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# El minimo de pedido que a habido es de 1 articulo
# y Maximo a habido pedidos de 64 articulos

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
filtro = df5[df5['add_to_cart_order'].isnull()]
id_s = filtro['order_id'].dropna().unique().tolist()
len(id_s)
# Out:
# 70

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
df5_nulos = df5[df5.isnull().any(axis=1)]
print(df5_nulos)
print( )
product_count= df5_nulos.groupby('order_id')['product_id'].count()
print(product_count)
min_value = product_count.min()
more_than_64 = min_value > 64

print("¿Todos los pedidos con valores ausentes tienen más de 64 productos?", more_than_64)
print("Cantidad mínima de productos en esos pedidos:", min_value)
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 737       2449164        5068                NaN          0
# 9926      1968313       43867                NaN          0
# 14394     2926893       11688                NaN          0
# 16418     1717990        4142                NaN          0
# 30114     1959075       42828                NaN          1
# ...           ...         ...                ...        ...
# 4505662   1800005        7411                NaN          0
# 4511400   1633337         260                NaN          0
# 4517562    404157        9517                NaN          0
# 4534112   1673227       17835                NaN          0
# 4535739   1832957       17949                NaN          1
#
# [836 rows x 4 columns]
#
# order_id
# 9310        1
# 61355      63
# 102236     31
# 129627      5
# 165801      6
#            ..
# 2999801     6
# 3125735    22
# 3308010    51
# 3347453     7
# 3383594     5
# ...

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
# Los pedidos con valores ausentes no son mayores a 64
# la cantidad minima de producto en estos pedidos es de 1

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
df5["add_to_cart_order"] = df5["add_to_cart_order"].fillna(999)
df5["add_to_cart_order"] = df5["add_to_cart_order"].astype(int)


print(df5.info())
print()
df5.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 138.7 MB
# None
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
# utilice fillna para remplezar los valores ausentes con 999
# y utilice asytpe para convertir todo lo que hay en la columna add_to_cart__order a numeros enteros

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo!
#
# Un valor mínimo de 1 tiene sentido porque cada pedido necesita, al menos, 1 artículo. Pero, un valor máximo de 64 resulta un tanto curioso. No hay ninguna razón (que no sea mera suerte) para que cualquiera pidiera más de 64 artículos en un pedido.
#
# Además, 64 enciende las alarmas porque es un número de base 2 muy común que surgen con asuntos de informática. Esta es una pista de que quizás el tipo database para esa columna solo admite almacenamiento de 64 bits.
#
# Luego, como era de esperarse, cada pedido relacionado con un valor ausente tiene más de 64 artículos en ella.
#
# Ya que no podemos saber en qué pedido se agregaron al carrito los artículos con valores ausentes para aquellos pedidos con más de 65 artículos, lo correcto es completar los valores ausentes con un valor de marcador de posición numérico que no pueda confundirse con daros reales; por ejemplo, 999.
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
horas_invalidas = df[~df['order_hour_of_day'].between(0, 23)]
dias_invalidos = df[~df['order_dow'].between(0, 6)]

print("Valores fuera de rango en 'order_hour_of_day':", len(horas_invalidas))
print("Valores fuera de rango en 'order_dow':", len(dias_invalidos))
# Out:
# Valores fuera de rango en 'order_hour_of_day': 0
# Valores fuera de rango en 'order_dow': 0

# %% [markdown]
# Escribe aquí tus conclusiones
# No tenemos valores fuera de los rangos, podemos proceder con el analisis

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Buen trabajo revisando los valores únicos.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
pedidos_por_hora = df.groupby('order_hour_of_day')['user_id'].nunique()

plt.figure(figsize=(10,6))
pedidos_por_hora.plot(kind='bar', title='Pedidos por hora', xlabel='Hora del dia', ylabel='Cantidad de personas', rot=45)
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# De acuerdo a la

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo al usar un gráfico de barras para visualizar los datos!
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Sin embargo, la comunicación de los resultados podría ser más precisa, por ejemplo se puede afirmar que: la mayoría de los pedidos ocurren entre las 9:00 AM y las 5:00 PM, con picos a las 10:00 AM y las 3:00 PM. Esto proporciona una gran perspectiva sobre el comportamiento del cliente.
#
# </div>
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
pedidos_por_dia = df.groupby('order_dow')['order_id'].count()
plt.figure(figsize=(10,6))
pedidos_por_dia.plot(kind='bar',title="Numero de pedidos por semana", xlabel="Dia de la semana, 0=Domingo", ylabel='Numero de pedidos')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los dias Domingo y lunes son los dias con mayor compra de viveres de la semana, el domingo es el dia con mas actividad

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# El uso de un gráfico de barras para representar los datos es acertado y ayuda a visualizar las tendencias claramente. Tu comunicación de resultados también es precisa: identificaste correctamente que, asumiendo que el domingo es 0, la mayoría de los pedidos se realizan el domingo y el lunes.
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
min_dias = df['days_since_prior_order'].min()
max_dias =  df['days_since_prior_order'].max()

print("Mínimo de días hasta otro pedido:", min_dias)
print("Máximo de días hasta otro pedido:", max_dias)
# Out:
# Mínimo de días hasta otro pedido: 0.0
# Máximo de días hasta otro pedido: 30.0

# %% [markdown]
# Escribe aquí tus conclusiones
# de acuerdo a la informacion de la columna "days_since_prior_order" las personas esperan minimo 0 dias (o sea personas que piden el mismo dia un nuevo pedido) y maximo 30 dias antes de realizar un nuevo pedido.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# No utilizaste un gráfico de barras, lo cual habría sido una herramienta útil para visualizar la distribución de los datos.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
miercoles = df[df['order_dow'] ==3]
sabado = df[df['order_dow'] ==6]

pedidos_miercoles = miercoles['order_hour_of_day'].value_counts().sort_index()
pedidos_sabado = sabado['order_hour_of_day'].value_counts().sort_index()
comparacion = pd.DataFrame({
    "Miercoles": pedidos_miercoles,
    "Sabado": pedidos_sabado
})
comparacion.plot(kind='bar', figsize=(12,6), title='Miercoles vs Sabado (Pedidos)', xlabel='Hora del dia', ylabel='Numero de pedidos')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# De acuerdo a la grafica podemos apreciar que tanto miercoles y sabado son muy similares, sin embargo, si ponemos mas atencion podemos notar que el sabado es ligeramente supierior al miercoles, estas evidencias son mas notorias en las horas picos del dia

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Identificaste correctamente una ligera disminución entre las 11h y las 13h los miércoles, que está ausente los sábados.
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
pedidos_por_usuario = df['user_id'].value_counts()
distribucion = pedidos_por_usuario.value_counts().sort_index()
distribucion.plot(kind='bar', title="Distribucion de ordenes por cliente", xlabel='Pedidos hechos', ylabel='Cantidad de cleintes')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# Como pueden apreciar en la grafica la por mucho destaca que la mayoria de los clientes realiza un pedido, conforme aumenta la cantidad de pedidos, la cantidad de clientes que las realizan disminuyen

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo Christian
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
productos_mas_pedidos = df5['product_id'].value_counts().head(20)
top_20_df = productos_mas_pedidos.reset_index()
top_20_df.columns = ['product_id', 'frecuencia']
print(top_20_df)

print()
print()
productos_mas_pedidos.plot(kind='bar', title='Top 20 productos mas pedidos', xlabel='Id del producto', ylabel='Cantidad de veces pedido')
plt.show()
# Out:
#     product_id  frecuencia
# 0        24852       66050
# 1        13176       53297
# 2        21137       37039
# 3        21903       33971
# 4        47209       29773
# 5        47766       24689
# 6        47626       21495
# 7        16797       20018
# 8        26209       19690
# 9        27845       19600
# 10       27966       19197
# 11       22935       15898
# 12       24964       15292
# 13       45007       14584
# 14       39275       13879
# 15       49683       13675
# 16       28204       12544
# 17        5876       12232
# 18        8277       11993
# 19       40706       11781

# %% [markdown]
# Escribe aquí tus conclusiones
# De acuerdo a la lista y a la grafica que tenemos los productos mas vendidos son el 24852 y 13176, revisando los documentos estos corresponderian a: Bananas & bolsa de bananas organicas (a las personas de alrededor les gustan muchos las bananas)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Correcto! Los productos populares se listan correctamente.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# En vez de mostrar el id del producto podrías mostrar el nombre del mismo.
# </div>
#
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
productos_por_pedido = df5.groupby('order_id')['product_id'].count()
productos_por_pedido.plot(kind='hist', bins=30, title="Distribucion del numero de productos por pedido", xlabel='Cantidad de productos en el pedido', ylabel='Numero de pedidos')
plt.show()

# %%
print(productos_por_pedido.describe())
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: product_id, dtype: float64

# %% [markdown]
# Escribe aquí tus conclusiones
# En promedio las personas se llevan 10 articulos por pedido, el mayor numero de articulos pedidos es 127 y el minimo es 1

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo! Efectivamente vemos que las personas generalmente realizan pedidos de entre 1 y 10 artículos.
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
productos_reordenados = df5[df5['reordered'] == 1]
top_reordenados = productos_reordenados['product_id'].value_counts().head(20).reset_index()
top_reordenados.columns = ['product_id', 'veces_reordenado']
top_con_nombre = top_reordenados.merge(df2[['product_id', 'product_name']], on='product_id', how='left')
top_con_nombre.set_index('product_name',inplace=True)
top_con_nombre['veces_reordenado'].plot(kind='bar', figsize=(12, 6), title='Top 20 productos mas reordenados', xlabel='Producto', ylabel='Veces reordenado')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Los articulos que se piden con mayor frecuencia son las bananas y la bolsa de bananas organicas

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Impecable, los resultados son los esperados.
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
total_pedidos = df5.groupby('product_id').size().rename('total_pedidos')
total_reordenados = df5[df5['reordered'] == 1].groupby('product_id').size().rename('total_reordenados')
proporciones = pd.concat([total_pedidos, total_reordenados], axis=1).fillna(0)
proporciones['proporcion_reorden'] = proporciones['total_reordenados'] / proporciones['total_pedidos']
proporciones = proporciones.reset_index().merge(df2[['product_id', 'product_name']], on='product_id', how='left')
top10 = proporciones.sort_values(by='proporcion_reorden', ascending=False).head(10)
top10.set_index('product_name')['proporcion_reorden'].plot(kind='bar', title='Top 10 productos con mayor proporcion de reorder', xlabel='Producto', ylabel='Proporcion de veces reordenado')
# Out:
# <AxesSubplot:title={'center':'Top 10 productos con mayor proporcion de reorder'}, xlabel='Producto', ylabel='Proporcion de veces reordenado'>

# %% [markdown]
# Escribe aquí tus conclusiones
# En esta grafica tenemos los 10 productos que mas suelen reordenarse (la verdad esperaba que en esta lista tambien estuvieran bananas jaja)

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
df_merged = df5.merge(df[['order_id', 'user_id']], on='order_id', how='left')

total_por_usuario = df_merged.groupby('user_id').size().rename('total_productos')

reordenados_por_usuario = df_merged[df_merged['reordered'] == 1].groupby('user_id').size().rename('productos_reordenados')

repeticion = pd.concat([total_por_usuario, reordenados_por_usuario], axis=1).fillna(0)
repeticion['tasa_repeticion'] = repeticion['productos_reordenados'] / repeticion['total_productos']

print(repeticion.head(20))
# Out:
#          total_productos  productos_reordenados  tasa_repeticion
# user_id
# 2                     26                    1.0         0.038462
# 4                      2                    0.0         0.000000
# 5                     12                    8.0         0.666667
# 6                      4                    0.0         0.000000
# 7                     14                   13.0         0.928571
# 11                    15                    3.0         0.200000
# 12                    12                    3.0         0.250000
# 13                    23                   13.0         0.565217
# 14                    61                   22.0         0.360656
# 15                    13                    7.0         0.538462
# 16                    32                   17.0         0.531250
# 17                    53                   38.0         0.716981
# 19                    48                   14.0         0.291667
# ...

# %%
plt.figure(figsize=(10, 6))
repeticion['tasa_repeticion'].plot(kind='hist', bins=30, title='Distribución de la tasa de repetición por usuario', xlabel='Tasa de repetición', ylabel='Número de usuarios')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# tenemos una gran cantidad de usuarios que no repiten productos, podrian ser compradores ocasionales? o quiza solo les gusta comprar cosas nuevas

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo. Los resultados son los esperados.
#
# Además, el plot es más que correcto!
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
primeros_productos = df5[df5['add_to_cart_order'] == 1]

conteo_primeros = primeros_productos['product_id'].value_counts().head(20)

top_primeros = conteo_primeros.reset_index()
top_primeros.columns = ['product_id', 'veces_primero']
top_primeros = top_primeros.merge(df2[['product_id', 'product_name']], on='product_id', how='left')

print(top_primeros[['product_name', 'veces_primero']])
# Out:
#                    product_name  veces_primero
# 0                        BANANA          15562
# 1        BAG OF ORGANIC BANANAS          11026
# 2            ORGANIC WHOLE MILK           4363
# 3          ORGANIC STRAWBERRIES           3946
# 4          ORGANIC HASS AVOCADO           3390
# 5          ORGANIC BABY SPINACH           3336
# 6               ORGANIC AVOCADO           3044
# 7                  SPRING WATER           2336
# 8                  STRAWBERRIES           2308
# 9           ORGANIC RASPBERRIES           2024
# 10   SPARKLING WATER GRAPEFRUIT           1914
# 11          ORGANIC HALF & HALF           1797
# 12                  LARGE LEMON           1737
# 13                         SODA           1733
# 14     ORGANIC REDUCED FAT MILK           1397
# 15                        LIMES           1370
# 16                HASS AVOCADOS           1340
# 17  ORGANIC REDUCED FAT 2% MILK           1310
# 18                  HALF & HALF           1309
# ...

# %%
plt.figure(figsize=(12,6))
top_primeros.set_index('product_name')['veces_primero'].plot(kind='bar', title='Top 20 productos agregados primero al carrito', xlabel='Producto', ylabel='Veces agregados primero')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
# En esta grafica se aprecia que las bananas y la bolsa de bananas organicas es el producto que mas ponen primero en su carrito (cielos a estas personas valla que les gustan las bananas)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Los productos se listan correctamente.
#
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Esta tienda tiene muy buenos clientes... clientes que les gustan las bananas DEMASIADO, podrian subirle el precio a las bananas
# ya que oferta y demanda? o mejor poner ofertas al producto mas vendido para poder retener a los clientes que ya tenemos
#
# Podriamos poner ofertas los dias domingo y lunes que son los dias mas concurridos, o quiza poner ofertan en los demas
# dias para aumentar la cantidad de gente en el resto de la semana.
#
# Las horas picos van desde las 9am a las 4pm podriamos poner ofertas a partir de las 5 de la tarde?
#
# el trabajo de un Data Scientist es dar informacion y dar sugerencias a
